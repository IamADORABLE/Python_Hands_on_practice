# %%
def print_board(b):
    print("\nBoard:")
    for r in b:
        print(" ".join(str(n) if n else "." for n in r))

def is_valid(b, r, c, n):
    return n not in b[r] and all(b[i][c] != n for i in range(5))

def play():
    board = [
    [1, 0, 5, 0, 3],
    [0, 4, 1, 0, 2],
    [0, 0, 0, 1, 0],
    [4, 0, 0, 2, 0],
    [0, 1, 0, 0, 5]
]


    while any(0 in row for row in board):
        print_board(board)
        try:
            r = int(input("Row (0-4): "))
            c = int(input("Col (0-4): "))
            n = int(input("Num (1-5): "))
            if board[r][c] != 0:
                print("❌ Filled.")
            elif is_valid(board, r, c, n):
                board[r][c] = n
            else:
                print("❌ Invalid.")
        except:
            print("⚠️ Try again.")

    print_board(board)
    print("🎉 Done!")

play()
# Out:
# Board:
# 1 . 5 . 3
# . 4 1 . 2
# . . . 1 .
# 4 . . 2 .
# . 1 . . 5
# Row (0-4): 0
# Col (0-4): 1
# Num (1-5): 2
#
# Board:
# 1 2 5 . 3
# . 4 1 . 2
# . . . 1 .
# 4 . . 2 .
# . 1 . . 5
# Row (0-4): 0
# Col (0-4): 3
# Num (1-5): 4
#
# Board:
# 1 2 5 4 3
# . 4 1 . 2
# . . . 1 .
# 4 . . 2 .
# . 1 . . 5
# Row (0-4): 1
# Col (0-4): 0
# Num (1-5): 3
#
# Board:
# 1 2 5 4 3
# 3 4 1 . 2
# . . . 1 .
# 4 . . 2 .
# . 1 . . 5
